# %%
import pandas
import numpy
from matplotlib import pyplot
from sklearn.linear_model import LinearRegression
import scipy.stats as stats
import math
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
# Gather data from CSVs exported from data scraping/cleaning notebook
MLBData = pandas.read_csv('MLBPlayerInfo.csv')
SoccerData = pandas.read_csv('SoccerPlayerInfo.csv')

# %% [markdown]
# # Is there a significant difference in BMI when comparing professional soccer and baseball players?

# %% [markdown]
# ### A. Starting with generic height/weight regression analysis

# %%
pyplot.scatter(MLBData['Height'], MLBData['Weight'], color='blue')
pyplot.title('Height/Weight of MLB Players')
pyplot.xlim(60, 85)
pyplot.ylim(90, 320)
pyplot.xlabel('Height (in)')
pyplot.ylabel('Weight (lbs)')
pyplot.show()

# %%
pyplot.scatter(SoccerData['Height'], SoccerData['Weight'], color='red')
pyplot.title('Height/Weight of Soccer Players')
pyplot.xlim(60, 85)
pyplot.ylim(90, 320)
pyplot.xlabel('Height (in)')
pyplot.ylabel('Weight (lbs)')
pyplot.show()

# %%
pyplot.scatter(MLBData['Height'], MLBData['Weight'], color='blue')
pyplot.scatter(SoccerData['Height'], SoccerData['Weight'], color='red')
pyplot.title('Comparing Height/Weight of MLB (Blue) and Soccer (Red) Players')
pyplot.xlim(60, 85)
pyplot.ylim(90, 320)
pyplot.xlabel('Height (in)')
pyplot.ylabel('Weight (lbs)')
pyplot.show()

# %% [markdown]
# **These plots show a general difference between sports in that soccer players are generally leaner with less variance than baseball players.**

# %%
SoccerReg = LinearRegression()
soc_x = SoccerData['Height'].values.reshape(-1,1)
soc_y = SoccerData['Weight'].values.reshape(-1,1)
SoccerReg.fit(soc_x, soc_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
MLBReg = LinearRegression()
mlb_x = MLBData['Height'].values.reshape(-1,1)
mlb_y = MLBData['Weight'].values.reshape(-1,1)
MLBReg.fit(mlb_x, mlb_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print('Slope of Soccer Height/Weight Regression: ', SoccerReg.coef_[0,0])
print('R-Squared of Soccer Height/Weight Regression: ', SoccerReg.score(soc_x, soc_y))
# Out:
# Slope of Soccer Height/Weight Regression:  4.846105111137425
# R-Squared of Soccer Height/Weight Regression:  0.5609594295550016

# %%
print('Slope of MLB Height/Weight Regression: ', MLBReg.coef_[0,0])
print('R-Squared of MLB Height/Weight Regression: ', MLBReg.score(mlb_x, mlb_y))
# Out:
# Slope of MLB Height/Weight Regression:  4.5926192417129
# R-Squared of MLB Height/Weight Regression:  0.24699218803061818

# %% [markdown]
# **These metrics make sense because both sports have a wide array of BMIs with such a large sample, especially a sport like baseball where we would expect a greater variation in BMI due to positions like catchers vs shortstops demanding different physical characteristics. This is represented through a much lower R-Squared in MLB data than soccer data due to a larger variance in player physicality. It can also be seen that generally weights of MLB players are higher than soccer based on the slopes representing weight/height ratio.**

# %% [markdown]
# ### B. Distribution and probability of BMI analysis

# %%
pyplot.hist(MLBData['BMI'], bins=25, density=1, color='blue')
pyplot.xlim(15, 40)
pyplot.title('Relative Freq. Histogram of MLB BMI')
pyplot.xlabel('BMI')
pyplot.ylabel('Relative Frequency')
pyplot.show()

# %%
pyplot.hist(SoccerData['BMI'], bins=25, density=1, color='red')
pyplot.xlim(15, 40)
pyplot.title('Relative Freq. Histogram of Soccer BMI')
pyplot.xlabel('BMI')
pyplot.ylabel('Relative Frequency')
pyplot.show()

# %%
pyplot.hist(MLBData['BMI'], bins=25, density=1, color='blue')
pyplot.hist(SoccerData['BMI'], bins=25, density=1, color='red')
pyplot.xlim(15, 40)
pyplot.title('Relative Freq. Histogram of Soccer (Red) and MLB (Blue) BMI')
pyplot.xlabel('BMI')
pyplot.ylabel('Relative Frequency')
pyplot.show()

# %%
print('Soccer BMI Mean: ', SoccerData['BMI'].mean())
print('MLB BMI Mean: ', MLBData['BMI'].mean())
print('Soccer BMI Standard Deviation: ', SoccerData['BMI'].std())
print('MLB BMI Standard Deviation: ', MLBData['BMI'].std())
# Out:
# Soccer BMI Mean:  23.07854060660071
# MLB BMI Mean:  26.945003613304507
# Soccer BMI Standard Deviation:  1.6381645793740578
# MLB BMI Standard Deviation:  2.3421206086706214

# %%
mu_soc = 23.093
sigma_soc = 1.6
mu_mlb = 26.945
sigma_mlb = 2.342

x_soc = numpy.linspace(mu_soc - 3 * sigma_soc, mu_soc + 3 * sigma_soc, 1000)
x_mlb = numpy.linspace(mu_mlb - 3 * sigma_mlb, mu_mlb + 3 * sigma_mlb, 1000)

y_soc = stats.norm.pdf(x_soc, mu_soc, sigma_soc)
y_mlb = stats.norm.pdf(x_mlb, mu_mlb, sigma_mlb)

pyplot.plot(x_soc, y_soc, color='red')
pyplot.plot(x_mlb, y_mlb, color='blue')

pyplot.title('Standardized Normal Distributions of Soccer (Red) and MLB (Blue) BMI')
pyplot.xlabel('BMI')
pyplot.ylabel('Relative Frequency')

pyplot.show()

# %%
soccer_prob = [x_soc, y_soc]
mlb_prob = [x_mlb, y_mlb]

def nearest_i(arr, val):
    array = numpy.asarray(arr)
    idx = (numpy.abs(array - val)).argmin()
    return idx

def sport_prob_bmi(bmi):
    # MLB Probability
    i_mlb = nearest_i(mlb_prob[0], bmi)
    prob_mlb = mlb_prob[1][i_mlb]
    
    # Soccer Probability
    i_soc = nearest_i(soccer_prob[0], bmi)
    prob_soc = soccer_prob[1][i_soc]
    
    total_prob = prob_mlb+prob_soc
    
    # Print Results
    print('Probability of EPL/MLS Soccer Player Based on BMI = ' + str(bmi) + ': ', prob_soc/total_prob)
    print('Probability of MLB Baseball Player Based on BMI = ' + str(bmi) + ': ', prob_mlb/total_prob)

# %% [markdown]
# ### Now that we have sport_prob_bmi which prints the relative probability of a soccer player based on EPL/MLS data vs the probability of an MLB player all based on normalized BMI distributions. Let's run some samples.

# %%
sport_prob_bmi(20)
print()
sport_prob_bmi(22)
print()
sport_prob_bmi(24)
print()
sport_prob_bmi(26)
print()
sport_prob_bmi(28)
print()
sport_prob_bmi(30)
# Out:
# Probability of EPL/MLS Soccer Player Based on BMI = 20:  0.9483040479882379
# Probability of MLB Baseball Player Based on BMI = 20:  0.051695952011762185
#
# Probability of EPL/MLS Soccer Player Based on BMI = 22:  0.9150605618020174
# Probability of MLB Baseball Player Based on BMI = 22:  0.08493943819798253
#
# Probability of EPL/MLS Soccer Player Based on BMI = 24:  0.733321829543923
# Probability of MLB Baseball Player Based on BMI = 24:  0.266678170456077
#
# Probability of EPL/MLS Soccer Player Based on BMI = 26:  0.2337541291491647
# Probability of MLB Baseball Player Based on BMI = 26:  0.7662458708508353
#
# Probability of EPL/MLS Soccer Player Based on BMI = 28:  0.017702499934628652
# Probability of MLB Baseball Player Based on BMI = 28:  0.9822975000653714
#
# Probability of EPL/MLS Soccer Player Based on BMI = 30:  0.036763966806304484
# Probability of MLB Baseball Player Based on BMI = 30:  0.9632360331936956

# %% [markdown]
# ### These results show the relative probabilities based on the standardized normal curves presented above, but how do they match up against our actual data?

# %%
def sport_based_bmi(bmi):
    # MLB Probability
    i_mlb = nearest_i(mlb_prob[0], bmi)
    prob_mlb = mlb_prob[1][i_mlb]
    
    # Soccer Probability
    i_soc = nearest_i(soccer_prob[0], bmi)
    prob_soc = soccer_prob[1][i_soc]
        
    # Return higher probability sport
    if prob_soc > prob_mlb:
        return 'Soccer'
    else:
        return 'Baseball'

# %%
MLBData['Sport Prediction'] = [sport_based_bmi(b) for b in MLBData['BMI']]
SoccerData['Sport Prediction'] = [sport_based_bmi(b) for b in SoccerData['BMI']]

# %%
MLBData.head(5)
# Out:
#    Unnamed: 0 Team             Name  Age Bats Throws  Height  Weight  \
# 0           0  ARI       Nick Ahmed   29    R      R      74     195
# 1           1  ARI  Abraham Almonte   30    B      R      69     210
# 2           2  ARI    Matt Andriese   29    R      R      74     225
# 3           3  ARI       Alex Avila   32    L      R      71     210
# 4           4  ARI   Archie Bradley   26    R      R      76     225
#
#   Years in League  Games Played  WAR        BMI Position Sport Prediction
# 0               6           158  4.3  25.033784       SS         Baseball
# 1               7            17  0.6  31.008192       RF         Baseball
# 2               5            54 -0.1  28.885135        P         Baseball
# 3              11            63  1.4  29.285856        C         Baseball
# 4               5            66  0.9  27.384868        P         Baseball

# %%
SoccerData.head(5)
# Out:
#    Unnamed: 0 League     Team             Name    Position  Age  Height  \
# 0           0    EPL  Arsenal       Bernd Leno  Goalkeeper   28      75
# 1           2    EPL  Arsenal  Héctor Bellerín    Defender   25      70
# 2           3    EPL  Arsenal   Calum Chambers    Defender   25      72
# 3           4    EPL  Arsenal      Rob Holding    Defender   24      72
# 4           5    EPL  Arsenal       Pablo Marí    Defender   26      75
#
#    Weight        BMI  Rating Sport Prediction
# 0     183  22.870933    6.88           Soccer
# 1     163  23.385510    6.63           Soccer
# 2     146  19.798997    6.86           Soccer
# 3     165  22.375579    6.25           Soccer
# 4     192  23.995733    7.37           Soccer

# %% [markdown]
# ### Now how often did our prediction match reality across EPL/MLS soccer data and MLB data?

# %%
mlb_size = len(MLBData.index)
mlb_predictions = len(MLBData[MLBData['Sport Prediction'] == 'Baseball'].index)
print('Accurate MLB Predictions: ' + str(mlb_predictions) + ' / ' + str(mlb_size) + ' = ', mlb_predictions/mlb_size)
# Out:
# Accurate MLB Predictions: 1262 / 1567 =  0.805360561582642

# %%
soccer_size = len(SoccerData.index)
soccer_predictions = len(SoccerData[SoccerData['Sport Prediction'] == 'Soccer'].index)
print('Accurate Soccer Predictions: ' + str(soccer_predictions) + ' / ' + str(soccer_size) + ' = ', soccer_predictions/soccer_size)
# Out:
# Accurate Soccer Predictions: 755 / 847 =  0.8913813459268005

# %%
print('Accurate Sport Predictions Across MLB/MLS/EPL Data: ' + str(soccer_predictions+mlb_predictions) + ' / ' + str(mlb_size+soccer_size) + ' = ', (soccer_predictions+mlb_predictions)/(soccer_size+mlb_size))
# Out:
# Accurate Sport Predictions Across MLB/MLS/EPL Data: 2017 / 2414 =  0.8355426677713339

# %% [markdown]
# ### I'd say that's not too bad. We were able to predict sport with about 83.6% accuracy across a large sampling of 2414 soccer and MLB player BMI's. Considering this is a classification problem with only two outcomes, we have a baseline accurac of 50%. This means our analysis provided a 30% improvement on baseline accuracy when predicting sport based on BMI.

# %% [markdown]
# ## As a small bonus, we'll use a simple machine learning model called a decision tree to see how much better we can predict sport based on BMI, Height, and Weight.

# %%
#Making a dataframe with all players of both sports, and only the necessary columns, height, weight, BMI, and Sport
# 0 = baseball, 1 = soccer

soccer = pandas.read_csv('SoccerPlayerInfo.csv')
ball = pandas.read_csv('MLBPlayerInfo.csv')
soccer['Sport'] = 1
ball['Sport'] = 0
soccerfiltered = pandas.DataFrame(soccer.loc[:, ['Height', 'Weight', 'BMI', 'Sport']])
ballfiltered = pandas.DataFrame(ball.loc[:, ['Height', 'Weight', 'BMI', 'Sport']])
both = pandas.concat([soccerfiltered, ballfiltered])
both.reset_index(inplace = True, drop = True)
both
# Out:
#       Height  Weight        BMI  Sport
# 0         75     183  22.870933      1
# 1         70     163  23.385510      1
# 2         72     146  19.798997      1
# 3         72     165  22.375579      1
# 4         75     192  23.995733      1
# ...      ...     ...        ...    ...
# 2409      74     185  23.750000      0
# 2410      75     200  24.995556      0
# 2411      74     201  25.804054      0
# 2412      75     220  27.495111      0
# 2413      75     215  26.870222      0
#
# [2414 rows x 4 columns]

# %% [markdown]
# ### Implementing the Decision Tree

# %%
model = DecisionTreeClassifier(max_depth = 11, criterion = 'entropy')

X = both[['BMI', 'Height', 'Weight']]
Y = both['Sport']

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.33, random_state = 42)
model.fit(x_train, y_train)

predictions = model.predict(x_test)
print('This model predicts sport accurately based on BMI {:.2f}'.format(accuracy_score(predictions, y_test) * 100),\
      '% of the time')
# Out:
# This model predicts sport accurately based on BMI 90.09 % of the time

# %% [markdown]
# ### This model predicts BMI about 7% better than our simple analysis of the normal distribution of BMI!!

# %% [markdown]
# ### Visualizing the decision tree. Below you can see the first three layers (of 11) of the decision tree, and the questions it is asking to determine what sport each height, weight, and BMI fit into!

# %%
fig, axes = pyplot.subplots(nrows = 1,ncols = 1,figsize = (4,5), dpi=1000)

plot_tree(model, feature_names = ['BMI', 'Height', 'Weight'], class_names = ['Soccer', 'Baseball'], \
          max_depth = 3, filled = True)
# Out:
# [Text(1798.0, 3397.5, 'Weight <= 187.5\nentropy = 0.927\nsamples = 1617\nvalue = [1063, 554]\nclass = Soccer'),
#  Text(992.0, 2642.5, 'Weight <= 174.5\nentropy = 0.789\nsamples = 648\nvalue = [153, 495]\nclass = Baseball'),
#  Text(496.0, 1887.5, 'Weight <= 159.5\nentropy = 0.471\nsamples = 408\nvalue = [41, 367]\nclass = Baseball'),
#  Text(248.0, 1132.5, 'Weight <= 150.5\nentropy = 0.139\nsamples = 205\nvalue = [4, 201]\nclass = Baseball'),
#  Text(124.0, 377.5, '\n  (...)  \n'),
#  Text(372.0, 377.5, '\n  (...)  \n'),
#  Text(744.0, 1132.5, 'BMI <= 22.325\nentropy = 0.685\nsamples = 203\nvalue = [37, 166]\nclass = Baseball'),
#  Text(620.0, 377.5, '\n  (...)  \n'),
#  Text(868.0, 377.5, '\n  (...)  \n'),
#  Text(1488.0, 1887.5, 'BMI <= 24.952\nentropy = 0.997\nsamples = 240\nvalue = [112, 128]\nclass = Baseball'),
#  Text(1240.0, 1132.5, 'BMI <= 24.473\nentropy = 0.953\nsamples = 174\nvalue = [65, 109]\nclass = Baseball'),
#  Text(1116.0, 377.5, '\n  (...)  \n'),
#  Text(1364.0, 377.5, '\n  (...)  \n'),
#  Text(1736.0, 1132.5, 'BMI <= 26.486\nentropy = 0.866\nsamples = 66\nvalue = [47, 19]\nclass = Soccer'),
#  Text(1612.0, 377.5, '\n  (...)  \n'),
#  Text(1860.0, 377.5, '\n  (...)  \n'),
#  Text(2604.0, 2642.5, 'BMI <= 25.465\nentropy = 0.331\nsamples = 969\nvalue = [910, 59]\nclass = Soccer'),
#  Text(2356.0, 1887.5, 'BMI <= 25.357\nentropy = 0.848\nsamples = 164\nvalue = [119, 45]\nclass = Soccer'),
#  Text(2232.0, 1132.5, 'Weight <= 199.0\nentropy = 0.814\nsamples = 159\nvalue = [119, 40]\nclass = Soccer'),
#  Text(2108.0, 377.5, '\n  (...)  \n'),
#  Text(2356.0, 377.5, '\n  (...)  \n'),
#  Text(2480.0, 1132.5, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Baseball'),
#  Text(2852.0, 1887.5, 'BMI <= 29.511\nentropy = 0.127\nsamples = 805\nvalue = [791, 14]\nclass = Soccer'),
#  Text(2728.0, 1132.5, 'BMI <= 29.474\nentropy = 0.146\nsamples = 672\nvalue = [658, 14]\nclass = Soccer'),
#  Text(2604.0, 377.5, '\n  (...)  \n'),
#  Text(2852.0, 377.5, '\n  (...)  \n'),
#  Text(2976.0, 1132.5, 'entropy = 0.0\nsamples = 133\nvalue = [133, 0]\nclass = Soccer')]

# %% [markdown]
# ## And finally here for fun you can see the whole decision tree! It is very hard to read when printed out so jumbled and small!

# %%
fig, axes = pyplot.subplots(nrows = 1,ncols = 1,figsize = (4,5), dpi=1000)

plot_tree(model, feature_names = ['BMI', 'Height', 'Weight'], class_names = ['Soccer', 'Baseball'], filled = True)
# Out:
# [Text(2008.2116788321168, 3617.7083333333335, 'Weight <= 187.5\nentropy = 0.927\nsamples = 1617\nvalue = [1063, 554]\nclass = Soccer'),
#  Text(1154.014598540146, 3303.125, 'Weight <= 174.5\nentropy = 0.789\nsamples = 648\nvalue = [153, 495]\nclass = Baseball'),
#  Text(371.0006082725061, 2988.541666666667, 'Weight <= 159.5\nentropy = 0.471\nsamples = 408\nvalue = [41, 367]\nclass = Baseball'),
#  Text(90.51094890510949, 2673.9583333333335, 'Weight <= 150.5\nentropy = 0.139\nsamples = 205\nvalue = [4, 201]\nclass = Baseball'),
#  Text(60.34063260340633, 2359.375, 'entropy = 0.0\nsamples = 109\nvalue = [0, 109]\nclass = Baseball'),
#  Text(120.68126520681265, 2359.375, 'Weight <= 151.5\nentropy = 0.25\nsamples = 96\nvalue = [4, 92]\nclass = Baseball'),
#  Text(60.34063260340633, 2044.7916666666667, 'Height <= 68.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = Soccer'),
#  Text(30.170316301703163, 1730.2083333333335, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Soccer'),
#  Text(90.51094890510949, 1730.2083333333335, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Baseball'),
#  Text(181.02189781021897, 2044.7916666666667, 'Weight <= 154.5\nentropy = 0.204\nsamples = 94\nvalue = [3, 91]\nclass = Baseball'),
#  Text(150.8515815085158, 1730.2083333333335, 'entropy = 0.0\nsamples = 41\nvalue = [0, 41]\nclass = Baseball'),
#  Text(211.19221411192214, 1730.2083333333335, 'Weight <= 155.5\nentropy = 0.314\nsamples = 53\nvalue = [3, 50]\nclass = Baseball'),
#  Text(181.02189781021897, 1415.625, 'BMI <= 23.226\nentropy = 0.61\nsamples = 20\nvalue = [3, 17]\nclass = Baseball'),
#  Text(150.8515815085158, 1101.041666666667, 'BMI <= 21.927\nentropy = 0.722\nsamples = 15\nvalue = [3, 12]\nclass = Baseball'),
#  Text(90.51094890510949, 786.4583333333335, 'BMI <= 20.734\nentropy = 0.863\nsamples = 7\nvalue = [2, 5]\nclass = Baseball'),
#  Text(60.34063260340633, 471.875, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Baseball'),
#  Text(120.68126520681265, 471.875, 'Height <= 71.5\nentropy = 0.918\nsamples = 6\nvalue = [2, 4]\nclass = Baseball'),
#  Text(90.51094890510949, 157.29166666666697, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = Soccer'),
#  Text(150.8515815085158, 157.29166666666697, 'entropy = 0.811\nsamples = 4\nvalue = [1, 3]\nclass = Baseball'),
#  Text(211.19221411192214, 786.4583333333335, 'BMI <= 22.562\nentropy = 0.544\nsamples = 8\nvalue = [1, 7]\nclass = Baseball'),
#  Text(181.02189781021897, 471.875, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Baseball'),
#  Text(241.3625304136253, 471.875, 'entropy = 0.811\nsamples = 4\nvalue = [1, 3]\nclass = Baseball'),
#  Text(211.19221411192214, 1101.041666666667, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Baseball'),
#  Text(241.3625304136253, 1415.625, 'entropy = 0.0\nsamples = 33\nvalue = [0, 33]\nclass = Baseball'),
#  Text(651.4902676399026, 2673.9583333333335, 'BMI <= 22.325\nentropy = 0.685\nsamples = 203\nvalue = [37, 166]\nclass = Baseball'),
#  Text(362.04379562043795, 2359.375, 'Weight <= 160.5\nentropy = 0.946\nsamples = 55\nvalue = [20, 35]\nclass = Baseball'),
#  Text(301.7031630170316, 2044.7916666666667, 'BMI <= 20.824\nentropy = 0.94\nsamples = 14\nvalue = [9, 5]\nclass = Soccer'),
#  Text(271.53284671532845, 1730.2083333333335, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Soccer'),
#  Text(331.8734793187348, 1730.2083333333335, 'BMI <= 22.005\nentropy = 0.961\nsamples = 13\nvalue = [8, 5]\nclass = Soccer'),
#  Text(301.7031630170316, 1415.625, 'Height <= 72.5\nentropy = 0.985\nsamples = 7\nvalue = [4, 3]\nclass = Soccer'),
#  Text(271.53284671532845, 1101.041666666667, 'entropy = 1.0\nsamples = 4\nvalue = [2, 2]\nclass = Soccer'),
#  Text(331.8734793187348, 1101.041666666667, 'entropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = Soccer'),
#  Text(362.04379562043795, 1415.625, 'entropy = 0.918\nsamples = 6\nvalue = [4, 2]\nclass = Soccer'),
#  Text(422.3844282238443, 2044.7916666666667, 'Weight <= 164.0\nentropy = 0.839\nsamples = 41\nvalue = [11, 30]\nclass = Baseball'),
#  Text(392.2141119221411, 1730.2083333333335, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Baseball'),
#  Text(452.55474452554745, 1730.2083333333335, 'Weight <= 171.0\nentropy = 0.878\nsamples = 37\nvalue = [11, 26]\nclass = Baseball'),
#  Text(422.3844282238443, 1415.625, 'BMI <= 20.534\nentropy = 0.908\nsamples = 34\nvalue = [11, 23]\nclass = Baseball'),
#  Text(392.2141119221411, 1101.041666666667, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Baseball'),
#  Text(452.55474452554745, 1101.041666666667, 'Height <= 75.5\nentropy = 0.928\nsamples = 32\nvalue = [11, 21]\nclass = Baseball'),
#  Text(422.3844282238443, 786.4583333333335, 'BMI <= 21.731\nentropy = 0.907\nsamples = 31\nvalue = [10, 21]\nclass = Baseball'),
#  Text(362.04379562043795, 471.875, 'BMI <= 21.632\nentropy = 0.977\nsamples = 17\nvalue = [7, 10]\nclass = Baseball'),
#  Text(331.8734793187348, 157.29166666666697, 'entropy = 0.954\nsamples = 16\nvalue = [6, 10]\nclass = Baseball'),
#  Text(392.2141119221411, 157.29166666666697, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Soccer'),
#  Text(482.7250608272506, 471.875, 'BMI <= 21.796\nentropy = 0.75\nsamples = 14\nvalue = [3, 11]\nclass = Baseball'),
#  Text(452.55474452554745, 157.29166666666697, 'entropy = 0.592\nsamples = 7\nvalue = [1, 6]\nclass = Baseball'),
#  Text(512.8953771289538, 157.29166666666697, 'entropy = 0.863\nsamples = 7\nvalue = [2, 5]\nclass = Baseball'),
#  Text(482.7250608272506, 786.4583333333335, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Soccer'),
#  Text(482.7250608272506, 1415.625, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Baseball'),
#  Text(940.9367396593674, 2359.375, 'BMI <= 25.691\nentropy = 0.514\nsamples = 148\nvalue = [17, 131]\nclass = Baseball'),
#  Text(765.5717761557178, 2044.7916666666667, 'Weight <= 164.0\nentropy = 0.462\nsamples = 143\nvalue = [14, 129]\nclass = Baseball'),
#  Text(633.5766423357665, 1730.2083333333335, 'BMI <= 23.027\nentropy = 0.179\nsamples = 37\nvalue = [1, 36]\nclass = Baseball'),
#  Text(603.4063260340632, 1415.625, 'Weight <= 160.5\nentropy = 0.391\nsamples = 13\nvalue = [1, 12]\nclass = Baseball'),
#  Text(573.2360097323601, 1101.041666666667, 'entropy = 0.592\nsamples = 7\nvalue = [1, 6]\nclass = Baseball'),
#  Text(633.5766423357665, 1101.041666666667, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Baseball'),
#  Text(663.7469586374696, 1415.625, 'entropy = 0.0\nsamples = 24\nvalue = [0, 24]\nclass = Baseball'),
#  Text(897.5669099756691, 1730.2083333333335, 'Weight <= 171.0\nentropy = 0.537\nsamples = 106\nvalue = [13, 93]\nclass = Baseball'),
#  Text(799.5133819951338, 1415.625, 'BMI <= 24.377\nentropy = 0.615\nsamples = 79\nvalue = [12, 67]\nclass = Baseball'),
#  Text(693.9172749391728, 1101.041666666667, 'Height <= 72.5\nentropy = 0.538\nsamples = 65\nvalue = [8, 57]\nclass = Baseball'),
#  Text(663.7469586374696, 786.4583333333335, 'Height <= 71.5\nentropy = 0.48\nsamples = 58\nvalue = [6, 52]\nclass = Baseball'),
#  Text(603.4063260340632, 471.875, 'BMI <= 24.233\nentropy = 0.422\nsamples = 35\nvalue = [3, 32]\nclass = Baseball'),
#  Text(573.2360097323601, 157.29166666666697, 'entropy = 0.362\nsamples = 29\nvalue = [2, 27]\nclass = Baseball'),
#  Text(633.5766423357665, 157.29166666666697, 'entropy = 0.65\nsamples = 6\nvalue = [1, 5]\nclass = Baseball'),
#  Text(724.0875912408759, 471.875, 'Weight <= 166.5\nentropy = 0.559\nsamples = 23\nvalue = [3, 20]\nclass = Baseball'),
#  Text(693.9172749391728, 157.29166666666697, 'entropy = 0.439\nsamples = 11\nvalue = [1, 10]\nclass = Baseball'),
#  Text(754.2579075425791, 157.29166666666697, 'entropy = 0.65\nsamples = 12\nvalue = [2, 10]\nclass = Baseball'),
#  Text(724.0875912408759, 786.4583333333335, 'entropy = 0.863\nsamples = 7\nvalue = [2, 5]\nclass = Baseball'),
#  Text(905.1094890510949, 1101.041666666667, 'BMI <= 25.094\nentropy = 0.863\nsamples = 14\nvalue = [4, 10]\nclass = Baseball'),
#  Text(874.9391727493918, 786.4583333333335, 'Weight <= 169.5\nentropy = 0.918\nsamples = 12\nvalue = [4, 8]\nclass = Baseball'),
#  Text(844.7688564476886, 471.875, 'Height <= 68.5\nentropy = 0.722\nsamples = 5\nvalue = [1, 4]\nclass = Baseball'),
#  Text(814.5985401459855, 157.29166666666697, 'entropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = Baseball'),
#  Text(874.9391727493918, 157.29166666666697, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Baseball'),
#  Text(905.1094890510949, 471.875, 'entropy = 0.985\nsamples = 7\nvalue = [3, 4]\nclass = Baseball'),
#  Text(935.2798053527981, 786.4583333333335, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Baseball'),
#  Text(995.6204379562043, 1415.625, 'Weight <= 173.0\nentropy = 0.229\nsamples = 27\nvalue = [1, 26]\nclass = Baseball'),
#  Text(965.4501216545012, 1101.041666666667, 'entropy = 0.0\nsamples = 14\nvalue = [0, 14]\nclass = Baseball'),
#  Text(1025.7907542579076, 1101.041666666667, 'Height <= 73.5\nentropy = 0.391\nsamples = 13\nvalue = [1, 12]\nclass = Baseball'),
#  Text(995.6204379562043, 786.4583333333335, 'BMI <= 23.275\nentropy = 0.503\nsamples = 9\nvalue = [1, 8]\nclass = Baseball'),
#  Text(965.4501216545012, 471.875, 'entropy = 0.65\nsamples = 6\nvalue = [1, 5]\nclass = Baseball'),
#  Text(1025.7907542579076, 471.875, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Baseball'),
#  Text(1055.9610705596108, 786.4583333333335, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Baseball'),
#  Text(1116.301703163017, 2044.7916666666667, 'BMI <= 26.936\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]\nclass = Soccer'),
#  Text(1086.1313868613138, 1730.2083333333335, 'Height <= 67.5\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]\nclass = Soccer'),
#  Text(1055.9610705596108, 1415.625, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Soccer'),
#  Text(1116.301703163017, 1415.625, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = Soccer'),
#  Text(1146.4720194647202, 1730.2083333333335, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Baseball'),
#  Text(1937.0285888077858, 2988.541666666667, 'BMI <= 24.952\nentropy = 0.997\nsamples = 240\nvalue = [112, 128]\nclass = Baseball'),
#  Text(1690.4805352798053, 2673.9583333333335, 'BMI <= 24.473\nentropy = 0.953\nsamples = 174\nvalue = [65, 109]\nclass = Baseball'),
#  Text(1660.3102189781023, 2359.375, 'BMI <= 24.339\nentropy = 0.977\nsamples = 158\nvalue = [65, 93]\nclass = Baseball'),
#  Text(1517.9440389294405, 2044.7916666666667, 'BMI <= 23.809\nentropy = 0.944\nsamples = 141\nvalue = [51, 90]\nclass = Baseball'),
#  Text(1384.0632603406327, 1730.2083333333335, 'BMI <= 21.922\nentropy = 0.973\nsamples = 124\nvalue = [50, 74]\nclass = Baseball'),
#  Text(1206.8126520681265, 1415.625, 'BMI <= 21.36\nentropy = 0.811\nsamples = 12\nvalue = [9, 3]\nclass = Soccer'),
#  Text(1146.4720194647202, 1101.041666666667, 'Height <= 77.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = Baseball'),
#  Text(1116.301703163017, 786.4583333333335, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Baseball'),
#  Text(1176.6423357664235, 786.4583333333335, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Soccer'),
#  Text(1267.153284671533, 1101.041666666667, 'Weight <= 177.5\nentropy = 0.503\nsamples = 9\nvalue = [8, 1]\nclass = Soccer'),
#  Text(1236.9829683698297, 786.4583333333335, 'entropy = 0.811\nsamples = 4\nvalue = [3, 1]\nclass = Soccer'),
#  Text(1297.3236009732361, 786.4583333333335, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Soccer'),
#  Text(1561.3138686131388, 1415.625, 'BMI <= 23.097\nentropy = 0.948\nsamples = 112\nvalue = [41, 71]\nclass = Baseball'),
#  Text(1433.0900243309002, 1101.041666666667, 'BMI <= 22.506\nentropy = 0.755\nsamples = 46\nvalue = [10, 36]\nclass = Baseball'),
#  Text(1357.6642335766423, 786.4583333333335, 'BMI <= 22.419\nentropy = 0.966\nsamples = 23\nvalue = [9, 14]\nclass = Baseball'),
#  Text(1297.3236009732361, 471.875, 'Weight <= 186.0\nentropy = 0.503\nsamples = 9\nvalue = [1, 8]\nclass = Baseball'),
#  Text(1267.153284671533, 157.29166666666697, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = Baseball'),
#  Text(1327.4939172749391, 157.29166666666697, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Soccer'),
#  Text(1418.0048661800488, 471.875, 'Height <= 74.5\nentropy = 0.985\nsamples = 14\nvalue = [8, 6]\nclass = Soccer'),
#  Text(1387.8345498783456, 157.29166666666697, 'entropy = 0.954\nsamples = 8\nvalue = [5, 3]\nclass = Soccer'),
#  Text(1448.1751824817518, 157.29166666666697, 'entropy = 1.0\nsamples = 6\nvalue = [3, 3]\nclass = Soccer'),
#  Text(1508.5158150851582, 786.4583333333335, 'BMI <= 23.033\nentropy = 0.258\nsamples = 23\nvalue = [1, 22]\nclass = Baseball'),
#  Text(1478.345498783455, 471.875, 'entropy = 0.0\nsamples = 19\nvalue = [0, 19]\nclass = Baseball'),
#  Text(1538.6861313868612, 471.875, 'entropy = 0.811\nsamples = 4\nvalue = [1, 3]\nclass = Baseball'),
#  Text(1689.5377128953771, 1101.041666666667, 'BMI <= 23.169\nentropy = 0.997\nsamples = 66\nvalue = [31, 35]\nclass = Baseball'),
#  Text(1629.197080291971, 786.4583333333335, 'BMI <= 23.114\nentropy = 0.874\nsamples = 17\nvalue = [12, 5]\nclass = Soccer'),
#  Text(1599.0267639902677, 471.875, 'entropy = 0.985\nsamples = 7\nvalue = [4, 3]\nclass = Soccer'),
#  Text(1659.367396593674, 471.875, 'entropy = 0.722\nsamples = 10\nvalue = [8, 2]\nclass = Soccer'),
#  Text(1749.8783454987836, 786.4583333333335, 'BMI <= 23.673\nentropy = 0.963\nsamples = 49\nvalue = [19, 30]\nclass = Baseball'),
#  Text(1719.7080291970804, 471.875, 'entropy = 0.0\nsamples = 14\nvalue = [0, 14]\nclass = Baseball'),
#  Text(1780.0486618004866, 471.875, 'Height <= 73.5\nentropy = 0.995\nsamples = 35\nvalue = [19, 16]\nclass = Soccer'),
#  Text(1749.8783454987836, 157.29166666666697, 'entropy = 0.9\nsamples = 19\nvalue = [13, 6]\nclass = Soccer'),
#  Text(1810.2189781021898, 157.29166666666697, 'entropy = 0.954\nsamples = 16\nvalue = [6, 10]\nclass = Baseball'),
#  Text(1651.8248175182482, 1730.2083333333335, 'BMI <= 24.208\nentropy = 0.323\nsamples = 17\nvalue = [1, 16]\nclass = Baseball'),
#  Text(1621.654501216545, 1415.625, 'entropy = 0.0\nsamples = 14\nvalue = [0, 14]\nclass = Baseball'),
#  Text(1681.9951338199514, 1415.625, 'entropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = Baseball'),
#  Text(1802.676399026764, 2044.7916666666667, 'BMI <= 24.407\nentropy = 0.672\nsamples = 17\nvalue = [14, 3]\nclass = Soccer'),
#  Text(1772.5060827250609, 1730.2083333333335, 'Weight <= 180.0\nentropy = 0.75\nsamples = 14\nvalue = [11, 3]\nclass = Soccer'),
#  Text(1742.3357664233577, 1415.625, 'entropy = 0.811\nsamples = 4\nvalue = [3, 1]\nclass = Soccer'),
#  Text(1802.676399026764, 1415.625, 'entropy = 0.722\nsamples = 10\nvalue = [8, 2]\nclass = Soccer'),
#  Text(1832.846715328467, 1730.2083333333335, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Soccer'),
#  Text(1720.6508515815085, 2359.375, 'entropy = 0.0\nsamples = 16\nvalue = [0, 16]\nclass = Baseball'),
#  Text(2183.5766423357663, 2673.9583333333335, 'BMI <= 26.486\nentropy = 0.866\nsamples = 66\nvalue = [47, 19]\nclass = Soccer'),
#  Text(2081.7518248175184, 2359.375, 'BMI <= 26.062\nentropy = 0.952\nsamples = 43\nvalue = [27, 16]\nclass = Soccer'),
#  Text(1998.7834549878346, 2044.7916666666667, 'BMI <= 25.66\nentropy = 0.852\nsamples = 36\nvalue = [26, 10]\nclass = Soccer'),
#  Text(1923.3576642335768, 1730.2083333333335, 'BMI <= 25.105\nentropy = 0.976\nsamples = 22\nvalue = [13, 9]\nclass = Soccer'),
#  Text(1863.0170316301703, 1415.625, 'Height <= 71.5\nentropy = 0.863\nsamples = 14\nvalue = [10, 4]\nclass = Soccer'),
#  Text(1832.846715328467, 1101.041666666667, 'entropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = Soccer'),
#  Text(1893.1873479318735, 1101.041666666667, 'entropy = 0.845\nsamples = 11\nvalue = [8, 3]\nclass = Soccer'),
#  Text(1983.698296836983, 1415.625, 'BMI <= 25.44\nentropy = 0.954\nsamples = 8\nvalue = [3, 5]\nclass = Baseball'),
#  Text(1953.5279805352798, 1101.041666666667, 'BMI <= 25.246\nentropy = 0.985\nsamples = 7\nvalue = [3, 4]\nclass = Baseball'),
#  Text(1893.1873479318735, 786.4583333333335, 'Weight <= 178.0\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]\nclass = Baseball'),
#  Text(1863.0170316301703, 471.875, 'entropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = Baseball'),
#  Text(1923.3576642335768, 471.875, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Baseball'),
#  Text(2013.8686131386862, 786.4583333333335, 'Weight <= 181.5\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = Soccer'),
#  Text(1983.698296836983, 471.875, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Soccer'),
#  Text(2044.0389294403894, 471.875, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = Soccer'),
#  Text(2013.8686131386862, 1101.041666666667, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Baseball'),
#  Text(2074.2092457420927, 1730.2083333333335, 'BMI <= 25.812\nentropy = 0.371\nsamples = 14\nvalue = [13, 1]\nclass = Soccer'),
#  Text(2044.0389294403894, 1415.625, 'entropy = 0.592\nsamples = 7\nvalue = [6, 1]\nclass = Soccer'),
#  Text(2104.3795620437954, 1415.625, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = Soccer'),
#  Text(2164.720194647202, 2044.7916666666667, 'Weight <= 183.5\nentropy = 0.592\nsamples = 7\nvalue = [1, 6]\nclass = Baseball'),
#  Text(2134.5498783454987, 1730.2083333333335, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Baseball'),
#  Text(2194.890510948905, 1730.2083333333335, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Soccer'),
#  Text(2285.401459854015, 2359.375, 'Height <= 66.5\nentropy = 0.559\nsamples = 23\nvalue = [20, 3]\nclass = Soccer'),
#  Text(2255.2311435523116, 2044.7916666666667, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Baseball'),
#  Text(2315.571776155718, 2044.7916666666667, 'Weight <= 186.0\nentropy = 0.439\nsamples = 22\nvalue = [20, 2]\nclass = Soccer'),
#  Text(2255.2311435523116, 1730.2083333333335, 'Weight <= 182.0\nentropy = 0.286\nsamples = 20\nvalue = [19, 1]\nclass = Soccer'),
#  Text(2225.0608272506083, 1415.625, 'BMI <= 26.592\nentropy = 0.544\nsamples = 8\nvalue = [7, 1]\nclass = Soccer'),
#  Text(2194.890510948905, 1101.041666666667, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = Soccer'),
#  Text(2255.2311435523116, 1101.041666666667, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = Soccer'),
#  Text(2285.401459854015, 1415.625, 'entropy = 0.0\nsamples = 12\nvalue = [12, 0]\nclass = Soccer'),
#  Text(2375.912408759124, 1730.2083333333335, 'BMI <= 27.629\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = Soccer'),
#  Text(2345.7420924574208, 1415.625, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Baseball'),
#  Text(2406.082725060827, 1415.625, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Soccer'),
#  Text(2862.4087591240877, 3303.125, 'BMI <= 25.465\nentropy = 0.331\nsamples = 969\nvalue = [910, 59]\nclass = Soccer'),
#  Text(2685.1581508515815, 2988.541666666667, 'BMI <= 25.357\nentropy = 0.848\nsamples = 164\nvalue = [119, 45]\nclass = Soccer'),
#  Text(2654.9878345498782, 2673.9583333333335, 'Weight <= 199.0\nentropy = 0.814\nsamples = 159\nvalue = [119, 40]\nclass = Soccer'),
#  Text(2556.934306569343, 2359.375, 'Weight <= 197.5\nentropy = 0.937\nsamples = 99\nvalue = [64, 35]\nclass = Soccer'),
#  Text(2526.76399026764, 2044.7916666666667, 'Weight <= 196.5\nentropy = 0.925\nsamples = 97\nvalue = [64, 33]\nclass = Soccer'),
#  Text(2496.593673965937, 1730.2083333333335, 'Weight <= 195.5\nentropy = 0.932\nsamples = 95\nvalue = [62, 33]\nclass = Soccer'),
#  Text(2466.4233576642337, 1415.625, 'Weight <= 194.5\nentropy = 0.911\nsamples = 92\nvalue = [62, 30]\nclass = Soccer'),
#  Text(2375.912408759124, 1101.041666666667, 'Weight <= 191.5\nentropy = 0.959\nsamples = 55\nvalue = [34, 21]\nclass = Soccer'),
#  Text(2345.7420924574208, 786.4583333333335, 'BMI <= 24.005\nentropy = 0.871\nsamples = 48\nvalue = [34, 14]\nclass = Soccer'),
#  Text(2285.401459854015, 471.875, 'BMI <= 22.827\nentropy = 0.722\nsamples = 20\nvalue = [16, 4]\nclass = Soccer'),
#  Text(2255.2311435523116, 157.29166666666697, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Soccer'),
#  Text(2315.571776155718, 157.29166666666697, 'entropy = 0.764\nsamples = 18\nvalue = [14, 4]\nclass = Soccer'),
#  Text(2406.082725060827, 471.875, 'Weight <= 190.5\nentropy = 0.94\nsamples = 28\nvalue = [18, 10]\nclass = Soccer'),
#  Text(2375.912408759124, 157.29166666666697, 'entropy = 0.951\nsamples = 27\nvalue = [17, 10]\nclass = Soccer'),
#  Text(2436.2530413625304, 157.29166666666697, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Soccer'),
#  Text(2406.082725060827, 786.4583333333335, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = Baseball'),
#  Text(2556.934306569343, 1101.041666666667, 'BMI <= 24.052\nentropy = 0.8\nsamples = 37\nvalue = [28, 9]\nclass = Soccer'),
#  Text(2496.593673965937, 786.4583333333335, 'Height <= 76.5\nentropy = 1.0\nsamples = 8\nvalue = [4, 4]\nclass = Soccer'),
#  Text(2466.4233576642337, 471.875, 'entropy = 1.0\nsamples = 4\nvalue = [2, 2]\nclass = Soccer'),
#  Text(2526.76399026764, 471.875, 'entropy = 1.0\nsamples = 4\nvalue = [2, 2]\nclass = Soccer'),
#  Text(2617.2749391727493, 786.4583333333335, 'BMI <= 24.702\nentropy = 0.663\nsamples = 29\nvalue = [24, 5]\nclass = Soccer'),
#  Text(2587.104622871046, 471.875, 'entropy = 0.696\nsamples = 16\nvalue = [13, 3]\nclass = Soccer'),
#  Text(2647.4452554744526, 471.875, 'entropy = 0.619\nsamples = 13\nvalue = [11, 2]\nclass = Soccer'),
#  Text(2526.76399026764, 1415.625, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Baseball'),
#  Text(2556.934306569343, 1730.2083333333335, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Soccer'),
#  Text(2587.104622871046, 2044.7916666666667, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Baseball'),
#  Text(2753.0413625304136, 2359.375, 'BMI <= 24.775\nentropy = 0.414\nsamples = 60\nvalue = [55, 5]\nclass = Soccer'),
#  Text(2677.615571776156, 2044.7916666666667, 'BMI <= 24.403\nentropy = 0.684\nsamples = 22\nvalue = [18, 4]\nclass = Soccer'),
#  Text(2617.2749391727493, 1730.2083333333335, 'BMI <= 24.286\nentropy = 0.323\nsamples = 17\nvalue = [16, 1]\nclass = Soccer'),
#  Text(2587.104622871046, 1415.625, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = Soccer'),
#  Text(2647.4452554744526, 1415.625, 'BMI <= 24.324\nentropy = 0.503\nsamples = 9\nvalue = [8, 1]\nclass = Soccer'),
#  Text(2617.2749391727493, 1101.041666666667, 'entropy = 0.811\nsamples = 4\nvalue = [3, 1]\nclass = Soccer'),
#  Text(2677.615571776156, 1101.041666666667, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Soccer'),
#  Text(2737.956204379562, 1730.2083333333335, 'BMI <= 24.586\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]\nclass = Baseball'),
#  Text(2707.785888077859, 1415.625, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Baseball'),
#  Text(2768.1265206812654, 1415.625, 'entropy = 1.0\nsamples = 4\nvalue = [2, 2]\nclass = Soccer'),
#  Text(2828.4671532846714, 2044.7916666666667, 'Height <= 75.5\nentropy = 0.176\nsamples = 38\nvalue = [37, 1]\nclass = Soccer'),
#  Text(2798.296836982968, 1730.2083333333335, 'entropy = 0.323\nsamples = 17\nvalue = [16, 1]\nclass = Soccer'),
#  Text(2858.6374695863747, 1730.2083333333335, 'entropy = 0.0\nsamples = 21\nvalue = [21, 0]\nclass = Soccer'),
#  Text(2715.3284671532847, 2673.9583333333335, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Baseball'),
#  Text(3039.6593673965936, 2988.541666666667, 'BMI <= 29.511\nentropy = 0.127\nsamples = 805\nvalue = [791, 14]\nclass = Soccer'),
#  Text(3009.489051094891, 2673.9583333333335, 'BMI <= 29.474\nentropy = 0.146\nsamples = 672\nvalue = [658, 14]\nclass = Soccer'),
#  Text(2979.3187347931876, 2359.375, 'BMI <= 28.661\nentropy = 0.138\nsamples = 671\nvalue = [658, 13]\nclass = Soccer'),
#  Text(2949.1484184914843, 2044.7916666666667, 'BMI <= 28.615\nentropy = 0.156\nsamples = 576\nvalue = [563, 13]\nclass = Soccer'),
#  Text(2918.978102189781, 1730.2083333333335, 'BMI <= 28.145\nentropy = 0.146\nsamples = 575\nvalue = [563, 12]\nclass = Soccer'),
#  Text(2888.807785888078, 1415.625, 'Height <= 76.5\nentropy = 0.165\nsamples = 494\nvalue = [482, 12]\nclass = Soccer'),
#  Text(2858.6374695863747, 1101.041666666667, 'BMI <= 26.313\nentropy = 0.182\nsamples = 435\nvalue = [423, 12]\nclass = Soccer'),
#  Text(2798.296836982968, 786.4583333333335, 'BMI <= 26.277\nentropy = 0.283\nsamples = 122\nvalue = [116, 6]\nclass = Soccer'),
#  Text(2768.1265206812654, 471.875, 'Weight <= 195.5\nentropy = 0.251\nsamples = 119\nvalue = [114, 5]\nclass = Soccer'),
#  Text(2737.956204379562, 157.29166666666697, 'entropy = 0.0\nsamples = 31\nvalue = [31, 0]\nclass = Soccer'),
#  Text(2798.296836982968, 157.29166666666697, 'entropy = 0.315\nsamples = 88\nvalue = [83, 5]\nclass = Soccer'),
#  Text(2828.4671532846714, 471.875, 'entropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = Soccer'),
#  Text(2918.978102189781, 786.4583333333335, 'BMI <= 27.118\nentropy = 0.137\nsamples = 313\nvalue = [307, 6]\nclass = Soccer'),
#  Text(2888.807785888078, 471.875, 'entropy = 0.0\nsamples = 134\nvalue = [134, 0]\nclass = Soccer'),
#  Text(2949.1484184914843, 471.875, 'BMI <= 27.121\nentropy = 0.212\nsamples = 179\nvalue = [173, 6]\nclass = Soccer'),
#  Text(2918.978102189781, 157.29166666666697, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = Soccer'),
#  Text(2979.3187347931876, 157.29166666666697, 'entropy = 0.186\nsamples = 177\nvalue = [172, 5]\nclass = Soccer'),
#  Text(2918.978102189781, 1101.041666666667, 'entropy = 0.0\nsamples = 59\nvalue = [59, 0]\nclass = Soccer'),
#  Text(2949.1484184914843, 1415.625, 'entropy = 0.0\nsamples = 81\nvalue = [81, 0]\nclass = Soccer'),
#  Text(2979.3187347931876, 1730.2083333333335, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Baseball'),
#  Text(3009.489051094891, 2044.7916666666667, 'entropy = 0.0\nsamples = 95\nvalue = [95, 0]\nclass = Soccer'),
#  Text(3039.6593673965936, 2359.375, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Baseball'),
#  Text(3069.829683698297, 2673.9583333333335, 'entropy = 0.0\nsamples = 133\nvalue = [133, 0]\nclass = Soccer')]
